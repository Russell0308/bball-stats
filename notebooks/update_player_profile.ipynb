# %% [markdown]
# Goal1 - season per game avgs

# %%
import pandas as pd
from nba_api.stats.endpoints import playerprofilev2

# %%
player_id = 1628983

# %%
player_profile = (playerprofilev2.PlayerProfileV2(player_id=player_id).get_data_frames())

# %%
player_profile
# Out:
# [   PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
#  0    1628983   2018-19        00  1610612746               LAC        20.0
#  1    1628983   2019-20        00  1610612760               OKC        21.0
#  2    1628983   2020-21        00  1610612760               OKC        22.0
#  3    1628983   2021-22        00  1610612760               OKC        23.0
#  4    1628983   2022-23        00  1610612760               OKC        24.0
#  5    1628983   2023-24        00  1610612760               OKC        25.0
#  6    1628983   2024-25        00  1610612760               OKC        26.0
#
#     GP  GS   MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
#  0  82  73  2174  341  ...   0.800    57   175  232  270   96   45  141  175
#  1  70  70  2428  478  ...   0.807    47   365  412  232   79   47  134  117
#  2  35  35  1180  287  ...   0.808    19   147  166  207   27   23  106   70
# ...

# %%
careertotalsregularseason = player_profile[0]

# %%
careertotalsregularseason
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2018-19        00  1610612746               LAC        20.0
# 1    1628983   2019-20        00  1610612760               OKC        21.0
# 2    1628983   2020-21        00  1610612760               OKC        22.0
# 3    1628983   2021-22        00  1610612760               OKC        23.0
# 4    1628983   2022-23        00  1610612760               OKC        24.0
# 5    1628983   2023-24        00  1610612760               OKC        25.0
# 6    1628983   2024-25        00  1610612760               OKC        26.0
#
#    GP  GS   MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  82  73  2174  341  ...   0.800    57   175  232  270   96   45  141  175
# 1  70  70  2428  478  ...   0.807    47   365  412  232   79   47  134  117
# 2  35  35  1180  287  ...   0.808    19   147  166  207   27   23  106   70
# ...

# %%
careertotalspostseason_df = player_profile[2]

# %%
careertotalspostseason_df
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2018-19        00  1610612746               LAC        20.0
# 1    1628983   2019-20        00  1610612760               OKC        21.0
# 2    1628983   2023-24        00  1610612760               OKC        25.0
#
#    GP  GS  MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0   6   6  173   28  ...   0.850     4    12   16   19    6    5    5  17   82
# 1   7   7  279   39  ...   0.957     3    34   37   29    7    3   15  17  114
# 2  10  10  399  111  ...   0.790     8    64   72   64   13   17   22  31  302
#
# [3 rows x 27 columns]

# %%
careertotalsallstarseason_df = player_profile[4]

# %%
careertotalsallstarseason_df
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2022-23        00  1610616833               GNS        24.0
# 1    1628983   2023-24        00  1610616834               WST        25.0
#
#    GP  GS  MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0   1   0   10    4  ...     0.0     2     0    2    7    0    0    0   0    9
# 1   1   1   28   12  ...     0.0     2     2    4    6    1    0    0   0   31
#
# [2 rows x 27 columns]
