# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import commonteamroster

import pandas as pd

# %%
teams_basic = pd.DataFrame(teams.get_teams())

# %%
team_id = teams_basic['id'][23]

# %%
data = commonteamroster.CommonTeamRoster(team_id).get_data_frames()

# %%
data[0]
# Out:
#         TeamID SEASON LeagueID                   PLAYER  NICKNAME  \
# 0   1610612760   2024       00             Malevy Leons    Malevy
# 1   1610612760   2024       00  Shai Gilgeous-Alexander      Shai
# 2   1610612760   2024       00             Dillon Jones    Dillon
# 3   1610612760   2024       00            Luguentz Dort  Luguentz
# 4   1610612760   2024       00          Jaylin Williams    Jaylin
# 5   1610612760   2024       00            Chet Holmgren      Chet
# 6   1610612760   2024       00           Jalen Williams     Jalen
# 7   1610612760   2024       00              Alex Caruso      Alex
# 8   1610612760   2024       00               Isaiah Joe    Isaiah
# 9   1610612760   2024       00            Ousmane Dieng   Ousmane
# 10  1610612760   2024       00             Adam Flagler      Adam
# 11  1610612760   2024       00            Aaron Wiggins     Aaron
# 12  1610612760   2024       00            Cason Wallace     Cason
# ...
