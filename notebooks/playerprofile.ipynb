# %%
from nba_api.stats.endpoints import playerprofilev2
from nba_api.stats.static import players

import pandas as pd

# %%
last_name = 'Gilgeous-Alexander'

# %%
player_df = pd.DataFrame(players.get_active_players())

# %%
def find_id(last_name):
    player = player_df[player_df['last_name'] == last_name]
    try:
        player_id = player['id'].iloc[0]
        return player_id
    except: 
        print(player)


player_id = find_id(last_name)

# %%
player_profile_list = playerprofilev2.PlayerProfileV2(player_id).get_data_frames()

# %% [markdown]
# ## Career Totals Regular Season by Year

# %%
player_profile_list[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2018-19        00  1610612746               LAC        20.0
# 1    1628983   2019-20        00  1610612760               OKC        21.0
# 2    1628983   2020-21        00  1610612760               OKC        22.0
# 3    1628983   2021-22        00  1610612760               OKC        23.0
# 4    1628983   2022-23        00  1610612760               OKC        24.0
# 5    1628983   2023-24        00  1610612760               OKC        25.0
# 6    1628983   2024-25        00  1610612760               OKC        26.0
#
#    GP  GS   MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  82  73  2174  341  ...   0.800    57   175  232  270   96   45  141  175
# 1  70  70  2428  478  ...   0.807    47   365  412  232   79   47  134  117
# 2  35  35  1180  287  ...   0.808    19   147  166  207   27   23  106   70
# ...

# %% [markdown]
# ## Career Totals Regular Season

# %%
player_profile_list[1]
# Out:
#    PLAYER_ID LEAGUE_ID  TEAM_ID   GP   GS    MIN   FGM   FGA  FG_PCT  FG3M  \
# 0    1628983        00        0  393  384  12916  3148  6353   0.496   464
#
#    ...  FT_PCT  OREB  DREB   REB   AST  STL  BLK  TOV   PF   PTS
# 0  ...   0.853   291  1587  1878  1924  547  300  904  894  8990
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Career Totals Post Season by Year

# %%
player_profile_list[2]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2018-19        00  1610612746               LAC        20.0
# 1    1628983   2019-20        00  1610612760               OKC        21.0
# 2    1628983   2023-24        00  1610612760               OKC        25.0
#
#    GP  GS  MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0   6   6  173   28  ...   0.850     4    12   16   19    6    5    5  17   82
# 1   7   7  279   39  ...   0.957     3    34   37   29    7    3   15  17  114
# 2  10  10  399  111  ...   0.790     8    64   72   64   13   17   22  31  302
#
# [3 rows x 27 columns]

# %% [markdown]
# ## Career Totals Post Season

# %%
player_profile_list[3]
# Out:
#    PLAYER_ID LEAGUE_ID  TEAM_ID  GP  GS  MIN  FGM  FGA  FG_PCT  FG3M  ...  \
# 0    1628983        00        0  23  23  850  178  374   0.476    39  ...
#
#    FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0   0.831    15   110  125  112   26   25   42  65  498
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Career Totals All-Star Games by year

# %%
player_profile_list[4]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2022-23        00  1610616833               GNS        24.0
# 1    1628983   2023-24        00  1610616834               WST        25.0
#
#    GP  GS  MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0   1   0   10    4  ...     0.0     2     0    2    7    0    0    0   0    9
# 1   1   1   28   12  ...     0.0     2     2    4    6    1    0    0   0   31
#
# [2 rows x 27 columns]

# %% [markdown]
# ## Career Totals All-Star Games

# %%
player_profile_list[5]
# Out:
#    PLAYER_ID LEAGUE_ID  TEAM_ID  GP  GS  MIN  FGM  FGA  FG_PCT  FG3M  ...  \
# 0    1628983        00        0   2   1   38   16   21   0.762     8  ...
#
#    FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0     0.0     4     2    6   13    1    0    0   0   40
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Career Totals College by Year

# %%
player_profile_list[6]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID  ORGANIZATION_ID SCHOOL_NAME  PLAYER_AGE  GP  \
# 0    1628983   2017-18        00             2852    Kentucky        19.0  37
#
#    GS   MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0  24  1248  183  ...   0.822    33   120  153  189   61   18   99  62  532
#
# [1 rows x 27 columns]

# %% [markdown]
# ## Career Totals College

# %%
player_profile_list[7]
# Out:
#    PLAYER_ID LEAGUE_ID  ORGANIZATION_ID  GP  GS   MIN  FGM  FGA  FG_PCT  FG3M  \
# 0    1628983        00                0  37  24  1248  183  377   0.485    23
#
#    ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0  ...   0.822    33   120  153  189   61   18   99  62  532
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Career Totals Pre-season by Year

# %%
player_profile_list[8]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628983   2018-19        00  1610612746               LAC        20.0
# 1    1628983   2019-20        00  1610612760               OKC        21.0
# 2    1628983   2020-21        00  1610612760               OKC        22.0
# 3    1628983   2021-22        00  1610612760               OKC        23.0
# 4    1628983   2023-24        00  1610612760               OKC        25.0
# 5    1628983   2024-25        00  1610612760               OKC        26.0
#
#    GP  GS  MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0   5   3  107   19  ...   0.625     3     9   12   19    8    1    4  13   46
# 1   7   7  170   41  ...   0.879     4    28   32   19    4    3   15   9  118
# 2   3   3   63   14  ...   0.727     0     7    7   12    3    2    5   3   38
# 3   3   3   63   11  ...   0.571     0     7    7   14    1    2    5   6   30
# ...

# %% [markdown]
# ## Career Totals Pre-season

# %%
player_profile_list[9]
# Out:
#    PLAYER_ID LEAGUE_ID  TEAM_ID  GP  GS  MIN  FGM  FGA  FG_PCT  FG3M  ...  \
# 0    1628983        00        0  23  21  507  105  217   0.484    26  ...
#
#    FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS
# 0   0.806     9    65   74   84   26   12   38  35  294
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Career rankings by Year

# %%
player_profile_list[10]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION PLAYER_AGE  GP  \
# 0    1628983   2018-19        00  1610612746               LAC         NR  NR
# 1    1628983   2019-20        00  1610612760               OKC         NR  NR
# 2    1628983   2020-21        00  1610612760               OKC         NR  NR
# 3    1628983   2021-22        00  1610612760               OKC         NR  NR
# 4    1628983   2022-23        00  1610612760               OKC         NR  NR
# 5    1628983   2023-24        00  1610612760               OKC         NR  NR
# 6    1628983   2024-25        00  1610612760               OKC         NR  NR
#
#    GS  RANK_MIN  RANK_FGM  ...  RANK_FT_PCT  RANK_OREB  RANK_DREB  RANK_REB  \
# 0  NR        74       101  ...           64        150        205       202
# 1  NR         8        25  ...           64        166         27        44
# 2  NR       212       106  ...           62        317        212       234
# ...

# %% [markdown]
# ## Career Playoff rankings by year

# %%
player_profile_list[11]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION PLAYER_AGE  GP  \
# 0    1628983   2018-19        00  1610612746               LAC         NR  NR
# 1    1628983   2019-20        00  1610612760               OKC         NR  NR
# 2    1628983   2023-24        00  1610612760               OKC         NR  NR
#
#    GS  RANK_MIN  RANK_FGM  ...  RANK_FT_PCT  RANK_OREB  RANK_DREB  RANK_REB  \
# 0  NR        80        71  ...           23         97        122       118
# 1  NR        46        56  ...            4        102         60        72
# 2  NR        33         9  ...           35         68         20        26
#
#    RANK_AST  RANK_STL  RANK_BLK  RANK_TOV  RANK_PTS  RANK_EFF
# 0        54        56        48       109        69        75
# 1        40        52        60        44        56        54
# 2        15        20         9        22        11        14
#
# [3 rows x 27 columns]

# %% [markdown]
# ## Season Highs

# %%
player_profile_list[12]
# Out:
#     PLAYER_ID     GAME_ID    GAME_DATE  VS_TEAM_ID VS_TEAM_CITY  \
# 0     1628983  0022400100  OCT 27 2024  1610612737      Atlanta
# 1     1628983  0022400100  OCT 27 2024  1610612737      Atlanta
# 2     1628983  0022400100  OCT 27 2024  1610612737      Atlanta
# 3     1628983  0022400091  OCT 26 2024  1610612741      Chicago
# 4     1628983  0022400075  OCT 24 2024  1610612743       Denver
# 5     1628983  0022400100  OCT 27 2024  1610612737      Atlanta
# 6     1628983  0022400163  NOV 04 2024  1610612753      Orlando
# 7     1628983  0022400150  NOV 02 2024  1610612746           LA
# 8     1628983  0022400100  OCT 27 2024  1610612737      Atlanta
# 9     1628983  0022400091  OCT 26 2024  1610612741      Chicago
# 10    1628983  0022400100  OCT 27 2024  1610612737      Atlanta
# 11    1628983  0022400075  OCT 24 2024  1610612743       Denver
# 12    1628983  0022400140  NOV 01 2024  1610612757     Portland
# 13    1628983  0022400100  OCT 27 2024  1610612737      Atlanta
# ...

# %% [markdown]
# ## Career Highs

# %%
player_profile_list[13]
# Out:
#     PLAYER_ID     GAME_ID    GAME_DATE  VS_TEAM_ID  VS_TEAM_CITY  \
# 0     1628983  0022200843  FEB 10 2023  1610612757      Portland
# 1     1628983  0022200488  DEC 23 2022  1610612740   New Orleans
# 2     1628983  0021900594  JAN 13 2020  1610612750     Minnesota
# 3     1628983  0022200773  FEB 01 2023  1610612745       Houston
# 4     1628983  0021900594  JAN 13 2020  1610612750     Minnesota
# 5     1628983  0022300710  FEB 04 2024  1610612761       Toronto
# 6     1628983  0022100979  MAR 08 2022  1610612749     Milwaukee
# 7     1628983  0022300021  NOV 14 2023  1610612759   San Antonio
# 8     1628983  0022200511  DEC 27 2022  1610612759   San Antonio
# 9     1628983  0022200146  NOV 07 2022  1610612765       Detroit
# 10    1628983  0021800606  JAN 08 2019  1610612766     Charlotte
# 11    1628983  0022300207  NOV 18 2023  1610612744  Golden State
# 12    1628983  0022301222  DEC 08 2023  1610612744  Golden State
# ...

# %% [markdown]
# ## Next Game

# %%
player_profile_list[14]
# Out:
#       GAME_ID    GAME_DATE GAME_TIME LOCATION  PLAYER_TEAM_ID  \
# 0  0022400177  NOV 06 2024  09:00 PM        A      1610612760
#
#   PLAYER_TEAM_CITY PLAYER_TEAM_NICKNAME PLAYER_TEAM_ABBREVIATION  VS_TEAM_ID  \
# 0    Oklahoma City              Thunder                      OKC  1610612743
#
#   VS_TEAM_CITY VS_TEAM_NICKNAME VS_TEAM_ABBREVIATION
# 0       Denver          Nuggets                  DEN
